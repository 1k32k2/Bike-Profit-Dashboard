# %%
import pandas as pd

# %%
df = pd.read_csv ('/content/bike_share_yr_1.csv')

# %%
df['dteday'] = pd.to_datetime(df['dteday'], format='%d/%m/%Y') # Specify the correct format '%d/%m/%Y' for day/month/year
df['dteday'] = df['dteday'].dt.strftime('%m/%d/%Y')

# %%
df
# Out:
#            dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0      01/01/2022       1   1     1   0        0        0           0
# 1      01/01/2022       1   1     1   1        0        0           0
# 2      01/01/2022       1   1     1   2        0        0           0
# 3      01/01/2022       1   1     1   3        0        0           0
# 4      01/01/2022       1   1     1   4        0        0           0
# ...           ...     ...  ..   ...  ..      ...      ...         ...
# 17463  12/31/2022       1   1    12  19        0        1           1
# 17464  12/31/2022       1   1    12  20        0        1           1
# 17465  12/31/2022       1   1    12  21        0        1           1
# 17466  12/31/2022       1   1    12  22        0        1           1
# 17467  12/31/2022       1   1    12  23        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  rider_type  riders
# ...

# %%
df.to_csv('bike_share_yr_1.csv', index=False)
